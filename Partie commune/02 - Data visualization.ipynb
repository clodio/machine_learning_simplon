# %% [markdown]
# # Data visualization
#
# Nous allons étudier les principales bibliothèques de visualisation des données Python

# %% [markdown]
# # 1 -- Matplotlib
#
# ---

# %% [markdown]
# ### Pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Graphiques simples

# %%
X = np.linspace(0, 2, 10) # on définit X. Il prend 10 valeurs entre 0 et 2 équiréparties
y = X**2 #on veut tracer la fonction y = X^2

plt.plot(X, y)
plt.show()

# %%
# le scatterplot ne relie pas les points

plt.scatter(X, y)
plt.show()

# %% [markdown]
# ### Styles Graphiques
# Il existe beaucoup de styles à ajouter aux graphiques. Voici les plus importants à retenir :
# - **c** : couleur de la ligne
# - **lw** : epaisseur de la ligne (pour les graphiques plot)
# - **ls** : style de la ligne (pour les graphiques plot)
# - **size** : taille du point (pour les graphiques scatter)
# - **marker** : style du point (pour les graphiques scatter)
# - **alpha** : transparence du graphique

# %%
plt.plot(X, y, c='red', lw=4, ls='--', alpha=0.8)
plt.show()

# %%
#proposer d'autres versions de ce graphe
plt.plot(X, y, c='blue', lw=3, ls='-.', alpha=0.8)
plt.show()

# %% [markdown]
# ## Cycle de vie d'une figure
# Pour créer des figures proprement, on doit suivre le cycle de vie suivant :
# 1. **plt.figure**(figsize())
# 2. **plt.plot()**
# 3. Extras (titre, axes, legendes)
# 4. **plt.show()**

# %%
X = np.linspace(0, 2, 10)

plt.figure() # Création d'une figure
plt.plot(X, X**2, label='quadratique') # premiere courbe
plt.plot(X, X**3, label='cubique') # deuxieme courbe
# Extra information
plt.title('figure 1') # titre
plt.xlabel('axe x') # axes
plt.ylabel('axe y') # axes
plt.legend() # legend

plt.savefig('figure.png') # sauvegarde la figure dans le repertoire de travail
plt.show() # affiche la figure

# %% [markdown]
# ## Subplots
# Les subplots sont un autre élément à ajouter pour créer plusieurs graphiques sur une même figure

# %%
plt.subplot(2, 1, 1)
plt.plot(X, y, c='red')
plt.subplot(2, 1, 2)
plt.plot(X, y, c='blue')

# %% [markdown]
# ## Méthode orientée objet

# %%
fig, ax = plt.subplots(2, 1, sharex=True) # partage le meme axe pour les subplots
ax[0].plot(X, y)
ax[1].plot(X, np.sin(X))
plt.show()

# %% [markdown]
# ## Exercice
# Créer une fonction "graphique" qui permet de tracer sur une seule et meme figure une série de graphiques issue d'une liste contenant plusieurs datasets :

# %%
def graphique(dataset):
    n = len(dataset)
   
    plt.figure(figsize=(20, 20))
    
    for k in range(0,n):
        plt.subplot(n, 1, k+1)
        plt.plot(dataset[k])
        plt.title("expérience "+str(k))
        
    plt.show()

# Voici le dataset utilisé
dataset = [ np.random.randn(100) for i in range(4)]
graphique(dataset)

# %%
# SOLUTION
def graphique(data):
    n = len(data)
   
    plt.figure(figsize=(12, 20))
    
    for k in  range(0,n):
        plt.subplot(n, 1, k+1)
        plt.plot(data[k])
        plt.title("expérience "+str(k))
        
    plt.show()

# %%
graphique(dataset)
# Out:
# 4

# %% [markdown]
# # 2 -- Graphiques avancés
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Graphique de Classification avec Scatter()

# %%
# !pip install scikit-learn
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target

print(f'x contient {x.shape[0]} exmples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exmples et 4 variables
# il y a 3 classes

# %%
n = x.shape[1]
plt.figure(figsize=(12, 8))
for i in range(n):
    plt.subplot(n//2, n//2, i+1)
    plt.scatter(x[:, 0], x[:, i], c=y)
    plt.xlabel('0')
    plt.ylabel(i)
    plt.colorbar(ticks=list(np.unique(y)))
plt.show()

# %% [markdown]
# ## Graphiques 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter(x[:, 0], x[:, 1], x[:,2], c=y)

# %% [markdown]
# ## Histogrammes

# %%
x = np.random.randn(1000)

plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist(x, bins=10)
plt.title('bins=10')
plt.subplot(122)
plt.hist(x, bins=50)
plt.title('bins= 50')
plt.show()

# %%
# histogramme d'une image
from scipy import misc
face = misc.face(gray=True)

plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.imshow(face, cmap='gray')
plt.subplot(122)
plt.hist(face.ravel(), bins=255)
plt.show()

# %% [markdown]
# # 3 -- Seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Pairplot() : La vue d'ensemble

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# ## Visualiser des catégories

# %%
titanic = sns.load_dataset('titanic')
titanic.drop(['alone', 'alive', 'who', 'adult_male', 'embark_town', 'class'], axis=1, inplace=True)
titanic.dropna(axis=0, inplace=True)
titanic.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C

# %%
sns.catplot(x='survived', y='age', data=titanic, hue='sex')

# %%
plt.figure(figsize=(32, 8))
sns.boxplot(x='pclass', y='fare', data=titanic, hue='sex')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='fare'>

# %% [markdown]
# ## Visualisation de Distributions

# %%
sns.distplot(titanic['fare'])
# Out:
# c:\bda\tools\python-3.6.8-amd64\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 4 Exercice

# %%
#charger le fichier 'homelessness.csv'

hl = pd.read_csv("homelessness.csv",sep=';')


#afficher les premières lignes 
hl.head(10)
# Out:
#                region                 state  individuals  family_members  \
# 0  East South Central               Alabama       2570.0           864.0
# 1             Pacific                Alaska       1434.0           582.0
# 2            Mountain               Arizona       7259.0          2606.0
# 3  West South Central              Arkansas       2280.0           432.0
# 4             Pacific            California     109008.0         20964.0
# 5            Mountain              Colorado       7607.0          3250.0
# 6         New England           Connecticut       2280.0          1696.0
# 7      South Atlantic              Delaware        708.0           374.0
# 8      South Atlantic  District of Columbia       3770.0          3134.0
# 9      South Atlantic               Florida      21443.0          9587.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588
# 5    5691287
# 6    3571520
# 7     965479
# 8     701547
# 9   21244317

# %%
hl_sorted_individuals =  hl.sort_values(['individuals'],ascending=False)

# %%
#faites un histogramme sur le nombre de sans-abri avec titre, légende
plt.figure(figsize=(12, 12))
plt.hist(hl['individuals'], bins=100)
plt.title('Hisitogramme des sans abris')
plt.legend(['Nb individus'])
plt.show()

# %%
#faites un bar plot avec les régions où il y a le plus de sans-abri  avec titre, légende
hl_sum_region = hl.groupby(['region'])['individuals'].sum()
hl_sum_region_sorted = hl_sum_region.sort_values(ascending=False)
hl_sum_region_sorted_top3 = hl_sum_region_sorted.nlargest(n=10)
hl_sum_region_sorted_top3.plot(kind='barh',legend=True)
plt.title('Histogramme des sans abris')
plt.legend(['Nb individus'])

# %%
import pandas as pd
from numpy.random import randint
import matplotlib.pyplot as plt
regions = hl['region'].unique()

# fig,axs = plt.subplots(len(regions),1, figsize = (20, 100), sharex=True)
fig, axes = plt.subplots(nrows=len(regions), ncols=1, figsize = (20, 100), sharex=True)

i=0
for region in regions:
    hl_region = hl[hl['region'] == region]
    hl_sum_state = hl_region.groupby(['state'])['individuals'].sum()
    hl_state_sorted = hl_sum_state.sort_values( ascending=False)
    plt.subplot(len(regions), 1, i+1)
    hl_state_sorted.plot(kind='barh', legend=True)
    #, ax=axes[i]
    # axs[i1]
    plt.title('Histogramme des sans abris ' + region)
    plt.legend(['Nb individus'])
    i=i+1

# %%
sns.distplot(hl['individuals'])
# Out:
# c:\bda\tools\python-3.6.8-amd64\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='individuals', ylabel='Density'>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# ax1 = hl.plot.scatter(x='individuals', y='width', c='DarkBlue')
sns.pairplot(hl, hue='region')

# %%
ax1 = hl.plot.scatter(x='individuals', y='family_members', c='DarkBlue')
